# %%
from modelscope.pipelines import pipeline
from modelscope.utils.constant import Tasks

model_id = 'damo/mplug_image-captioning_coco_base_zh'
input_caption = 'https://alice-open.oss-cn-zhangjiakou.aliyuncs.com/mPLUG/image_captioning.png'

pipeline_caption = pipeline(Tasks.image_captioning, model=model_id)
result = pipeline_caption(input_caption)
print(result)
# Out:
# 2023-11-30 16:59:53,473 - modelscope - WARNING - Model revision not specified, use revision: v1.0.1
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/Library/Caches/pypoetry/virtualenvs/huggingface-learning-R1GBXbBC-py3.11/lib/python3.11/site-packages/modelscope/utils/import_utils.py:439, in LazyImportModule._get_module(self, module_name)
#     438         requires(module_name_full, requirements)
# --> 439     return importlib.import_module('.' + module_name, self.__name__)
#     440 except Exception as e:
#
# File ~/.pyenv/versions/3.11.3/lib/python3.11/importlib/__init__.py:126, in import_module(name, package)
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1206, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1178, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1149, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:690, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:940, in exec_module(self, module)
#
# File <frozen importlib._bootstrap>:241, in _call_with_frames_removed(f, *args, **kwds)
#
# File ~/Library/Caches/pypoetry/virtualenvs/huggingface-learning-R1GBXbBC-py3.11/lib/python3.11/site-packages/modelscope/models/multi_modal/ofa_for_all_tasks.py:18
#      17 from modelscope.outputs import OutputKeys
# ---> 18 from modelscope.preprocessors.ofa.utils.collate import collate_tokens
#      19 from modelscope.utils.config import Config
#
# File ~/Library/Caches/pypoetry/virtualenvs/huggingface-learning-R1GBXbBC-py3.11/lib/python3.11/site-packages/modelscope/preprocessors/ofa/__init__.py:2
#       1 # Copyright (c) Alibaba, Inc. and its affiliates.
# ----> 2 from .asr import OfaASRPreprocessor
#       3 from .image_captioning import OfaImageCaptioningPreprocessor
#
# File ~/Library/Caches/pypoetry/virtualenvs/huggingface-learning-R1GBXbBC-py3.11/lib/python3.11/site-packages/modelscope/preprocessors/ofa/asr.py:11
#      10 import torch
# ---> 11 from fairseq.data.audio.feature_transforms import \
#      12     CompositeAudioFeatureTransform
#      13 from fairseq.data.audio.speech_to_text_dataset import S2TDataConfig
#
# File ~/Library/Caches/pypoetry/virtualenvs/huggingface-learning-R1GBXbBC-py3.11/lib/python3.11/site-packages/fairseq/__init__.py:20
#      19 # backwards compatibility to support `from fairseq.X import Y`
# ---> 20 from fairseq.distributed import utils as distributed_utils
#      21 from fairseq.logging import meters, metrics, progress_bar  # noqa
#
# File ~/Library/Caches/pypoetry/virtualenvs/huggingface-learning-R1GBXbBC-py3.11/lib/python3.11/site-packages/fairseq/distributed/__init__.py:7
#       6 from .distributed_timeout_wrapper import DistributedTimeoutWrapper
# ----> 7 from .fully_sharded_data_parallel import (
#       8     fsdp_enable_wrap,
#       9     fsdp_wrap,
#      10     FullyShardedDataParallel,
#      11 )
#      12 from .legacy_distributed_data_parallel import LegacyDistributedDataParallel
#
# File ~/Library/Caches/pypoetry/virtualenvs/huggingface-learning-R1GBXbBC-py3.11/lib/python3.11/site-packages/fairseq/distributed/fully_sharded_data_parallel.py:10
#       9 import torch
# ---> 10 from fairseq.dataclass.configs import DistributedTrainingConfig
#      11 from fairseq.distributed import utils as dist_utils
#
# File ~/Library/Caches/pypoetry/virtualenvs/huggingface-learning-R1GBXbBC-py3.11/lib/python3.11/site-packages/fairseq/dataclass/__init__.py:6
#       1 # Copyright (c) Facebook, Inc. and its affiliates.
#       2 #
#       3 # This source code is licensed under the MIT license found in the
#       4 # LICENSE file in the root directory of this source tree.
# ----> 6 from .configs import FairseqDataclass
#       7 from .constants import ChoiceEnum
#
# File ~/Library/Caches/pypoetry/virtualenvs/huggingface-learning-R1GBXbBC-py3.11/lib/python3.11/site-packages/fairseq/dataclass/configs.py:1104
#    1098     ema_fp32: bool = field(
#    1099         default=False,
#    1100         metadata={"help": "If true, store EMA model in fp32 even if model is in fp16"},
#    1101     )
# -> 1104 @dataclass
#    1105 class FairseqConfig(FairseqDataclass):
#    1106     common: CommonConfig = CommonConfig()
#
# File ~/.pyenv/versions/3.11.3/lib/python3.11/dataclasses.py:1223, in dataclass(cls, init, repr, eq, order, unsafe_hash, frozen, match_args, kw_only, slots, weakref_slot)
#    1222 # We're called as @dataclass without parens.
# -> 1223 return wrap(cls)
#
# File ~/.pyenv/versions/3.11.3/lib/python3.11/dataclasses.py:1213, in dataclass.<locals>.wrap(cls)
#    1212 def wrap(cls):
# -> 1213     return _process_class(cls, init, repr, eq, order, unsafe_hash,
#    1214                           frozen, match_args, kw_only, slots,
#    1215                           weakref_slot)
#
# File ~/.pyenv/versions/3.11.3/lib/python3.11/dataclasses.py:958, in _process_class(cls, init, repr, eq, order, unsafe_hash, frozen, match_args, kw_only, slots, weakref_slot)
#     956     else:
#     957         # Otherwise it's a field of some type.
# --> 958         cls_fields.append(_get_field(cls, name, type, kw_only))
#     960 for f in cls_fields:
#
# File ~/.pyenv/versions/3.11.3/lib/python3.11/dataclasses.py:815, in _get_field(cls, a_name, a_type, default_kw_only)
#     814 if f._field_type is _FIELD and f.default.__class__.__hash__ is None:
# --> 815     raise ValueError(f'mutable default {type(f.default)} for field '
#     816                      f'{f.name} is not allowed: use default_factory')
#     818 return f
#
# ValueError: mutable default <class 'fairseq.dataclass.configs.CommonConfig'> for field common is not allowed: use default_factory
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[7], line 7
#       4 model_id = 'damo/mplug_image-captioning_coco_base_zh'
#       5 input_caption = 'https://alice-open.oss-cn-zhangjiakou.aliyuncs.com/mPLUG/image_captioning.png'
# ----> 7 pipeline_caption = pipeline(Tasks.image_captioning, model=model_id)
#       8 result = pipeline_caption(input_caption)
#       9 print(result)
#
# File ~/Library/Caches/pypoetry/virtualenvs/huggingface-learning-R1GBXbBC-py3.11/lib/python3.11/site-packages/modelscope/pipelines/builder.py:162, in pipeline(task, model, preprocessor, config_file, pipeline_name, framework, device, model_revision, ignore_file_pattern, **kwargs)
#     159 if preprocessor is not None:
#     160     cfg.preprocessor = preprocessor
# --> 162 return build_pipeline(cfg, task_name=task)
#
# File ~/Library/Caches/pypoetry/virtualenvs/huggingface-learning-R1GBXbBC-py3.11/lib/python3.11/site-packages/modelscope/pipelines/builder.py:65, in build_pipeline(cfg, task_name, default_args)
#      54 def build_pipeline(cfg: ConfigDict,
#      55                    task_name: str = None,
#      56                    default_args: dict = None):
#      57     """ build pipeline given model config dict.
#      58
#      59     Args:
#    (...)
#      63         default_args (dict, optional): Default initialization arguments.
#      64     """
# ---> 65     return build_from_cfg(
#      66         cfg, PIPELINES, group_key=task_name, default_args=default_args)
#
# File ~/Library/Caches/pypoetry/virtualenvs/huggingface-learning-R1GBXbBC-py3.11/lib/python3.11/site-packages/modelscope/utils/registry.py:184, in build_from_cfg(cfg, registry, group_key, default_args)
#     182 from modelscope.utils.import_utils import LazyImportModule
#     183 sig = (registry.name.upper(), group_key, cfg['type'])
# --> 184 LazyImportModule.import_module(sig)
#     186 args = cfg.copy()
#     187 if default_args is not None:
#
# File ~/Library/Caches/pypoetry/virtualenvs/huggingface-learning-R1GBXbBC-py3.11/lib/python3.11/site-packages/modelscope/utils/import_utils.py:463, in LazyImportModule.import_module(signature)
#     460         requirements = LazyImportModule.AST_INDEX[REQUIREMENT_KEY][
#     461             module_name]
#     462         requires(module_name, requirements)
# --> 463     importlib.import_module(module_name)
#     464 else:
#     465     logger.warning(f'{signature} not found in ast index file')
#
# File ~/.pyenv/versions/3.11.3/lib/python3.11/importlib/__init__.py:126, in import_module(name, package)
#     124             break
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1206, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1178, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1149, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:690, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:940, in exec_module(self, module)
#
# File <frozen importlib._bootstrap>:241, in _call_with_frames_removed(f, *args, **kwds)
#
# File ~/Library/Caches/pypoetry/virtualenvs/huggingface-learning-R1GBXbBC-py3.11/lib/python3.11/site-packages/modelscope/pipelines/multi_modal/image_captioning_pipeline.py:8
#       5 import torch
#       7 from modelscope.metainfo import Pipelines
# ----> 8 from modelscope.models.multi_modal import (CLIP_Interrogator, MPlugForAllTasks,
#       9                                            OfaForAllTasks)
#      10 from modelscope.pipelines.base import Model, Pipeline
#      11 from modelscope.pipelines.builder import PIPELINES
#
# File <frozen importlib._bootstrap>:1231, in _handle_fromlist(module, fromlist, import_, recursive)
#
# File ~/Library/Caches/pypoetry/virtualenvs/huggingface-learning-R1GBXbBC-py3.11/lib/python3.11/site-packages/modelscope/utils/import_utils.py:422, in LazyImportModule.__getattr__(self, name)
#     420     value = self._get_module(name)
#     421 elif name in self._class_to_module.keys():
# --> 422     module = self._get_module(self._class_to_module[name])
#     423     value = getattr(module, name)
#     424 else:
#
# File ~/Library/Caches/pypoetry/virtualenvs/huggingface-learning-R1GBXbBC-py3.11/lib/python3.11/site-packages/modelscope/utils/import_utils.py:441, in LazyImportModule._get_module(self, module_name)
#     439     return importlib.import_module('.' + module_name, self.__name__)
#     440 except Exception as e:
# --> 441     raise RuntimeError(
#     442         f'Failed to import {self.__name__}.{module_name} because of the following error '
#     443         f'(look up to see its traceback):\n{e}') from e
#
# RuntimeError: Failed to import modelscope.models.multi_modal.ofa_for_all_tasks because of the following error (look up to see its traceback):
# mutable default <class 'fairseq.dataclass.configs.CommonConfig'> for field common is not allowed: use default_factory
